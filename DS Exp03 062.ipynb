# %% [markdown]
# ## Experiment No. 03
# ## Shubham Anil Khalate
# ## 2317062
# ## AIDS-A3

# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df["age"].count()
# Out:
# 48842

# %%
df["educational-num"].mean()
# Out:
# 10.078088530363212

# %%
df["age"].min()
# Out:
# 17

# %%
df["age"].max()
# Out:
# 90

# %%
df.size
# Out:
# 732630

# %%
df["age"].mean()
# Out:
# 38.64358543876172

# %%
df.shape
# Out:
# (48842, 15)

# %%
df["occupation"].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df["occupation"].value_counts().count()
# Out:
# 15

# %%
df["income"].value_counts()
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
df["age"].where
# Out:
# <bound method Series.where of 0        25
# 1        38
# 2        28
# 3        44
# 4        18
#          ..
# 48837    27
# 48838    40
# 48839    58
# 48840    22
# 48841    52
# Name: age, Length: 48842, dtype: int64>

# %%
df["age"].isnull().count()
# Out:
# 48842

# %%
df["age"].notnull().count()
# Out:
# 48842

# %%
df["hours-per-week"].notnull().count()
# Out:
# 48842

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
df["race"].value_counts()
# Out:
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: count, dtype: int64

# %%
df["workclass"].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df["age"].astype
# Out:
# <bound method NDFrame.astype of 0        25
# 1        38
# 2        28
# 3        44
# 4        18
#          ..
# 48837    27
# 48838    40
# 48839    58
# 48840    22
# 48841    52
# Name: age, Length: 48842, dtype: int64>

# %%
df["fnlwgt"].value_counts().count()
# Out:
# 28523

# %%
df["workclass"].value_counts().count()
# Out:
# 9

# %%
df["educational-num"].where
# Out:
# <bound method Series.where of 0         7
# 1         9
# 2        12
# 3        10
# 4        10
#          ..
# 48837    12
# 48838     9
# 48839     9
# 48840     9
# 48841     9
# Name: educational-num, Length: 48842, dtype: int64>

# %%
df.where()
# Out:
# <bound method DataFrame.where of        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
ages=df["age"]

# %%
df.where(ages>50)
# Out:
#         age     workclass    fnlwgt education  educational-num  \
# 0       NaN           NaN       NaN       NaN              NaN
# 1       NaN           NaN       NaN       NaN              NaN
# 2       NaN           NaN       NaN       NaN              NaN
# 3       NaN           NaN       NaN       NaN              NaN
# 4       NaN           NaN       NaN       NaN              NaN
# ...     ...           ...       ...       ...              ...
# 48837   NaN           NaN       NaN       NaN              NaN
# 48838   NaN           NaN       NaN       NaN              NaN
# 48839  58.0       Private  151910.0   HS-grad              9.0
# 48840   NaN           NaN       NaN       NaN              NaN
# 48841  52.0  Self-emp-inc  287927.0   HS-grad              9.0
#
#            marital-status       occupation relationship   race  gender  \
# 0                     NaN              NaN          NaN    NaN     NaN
# ...

# %%
df.where(ages>50).value_counts().count()
# Out:
# 9807

# %%
df["age"].where(ages>50).dropna().count()
# Out:
# 9808

# %%
df1=df.groupby(['income','age','gender'])

# %%
print(df1.first())
# Out:
#                           workclass  fnlwgt     education  educational-num  \
# income age gender
# <=50K  17  Female           Private   40299          11th                7
#            Male             Private  269430          10th                6
#        18  Female                 ?  103497  Some-college               10
#            Male             Private   54440  Some-college               10
#        19  Female           Private  355313       HS-grad                9
# ...                             ...     ...           ...              ...
# >50K   84  Male        Self-emp-inc  172907  Some-college               10
#        85  Male        Self-emp-inc  155981     Bachelors               13
#        88  Male    Self-emp-not-inc  263569          11th                7
#        90  Female           Private  197613       HS-grad                9
#            Male             Private  149069    Assoc-acdm               12
#
# ...
